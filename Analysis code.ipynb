# %%
pip install spacy-sentence-bert
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 46.9 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 46.5 MB/s
# ...
#      |████████████████████████████████| 120 kB 42.0 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 38.7 MB/s
# ...
#   Created wheel for spacy-sentence-bert: filename=spacy_sentence_bert-0.1.2-py3-none-any.whl size=27202 sha256=d83de438496f564b72c5b95189756ecbe63d4b50eede53070da70b9d69a59391
#   Stored in directory: /root/.cache/pip/wheels/54/e2/4a/e3f24fb6729ada3c83377de5217261c0e2f153c5a6f36d37d0
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=6bc289a885de4276078650c9964307009a4b71cc5be9c3f8fa319957b02da84d
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# ...

# %%
pip install spacy-sentence-bert==0.0.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 10.4 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 184 kB 66.4 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 62.3 MB/s
# ...
#   Created wheel for spacy-sentence-bert: filename=spacy_sentence_bert-0.0.3-py3-none-any.whl size=16652 sha256=32558c891afcd7afb1c9db8fcc758b6f869d2e0267360fc50e3c9fef645a3bc7
#   Stored in directory: /root/.cache/pip/wheels/12/70/2c/3d6931fcae3984f505387af363dcd6cf304df248f7d3ec81fb
# Successfully built spacy-sentence-bert
# ...
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.4
#     Uninstalling srsly-2.4.4:
#       Successfully uninstalled srsly-2.4.4
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.8
#     Uninstalling catalogue-2.0.8:
#       Successfully uninstalled catalogue-2.0.8
#   Attempting uninstall: thinc
# ...

# %%
import spacy_sentence_bert
import pandas as pd

nlp = spacy_sentence_bert.load_model('en_bert_base_nli_cls_token')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.57k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/623 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/395 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
df = pd.read_excel('Chat Bot Validation.xlsx')

# %%
similarityValue = []

for i in range(df.count()[0]):
    sentence_1 = nlp(df.iloc[i][0])
    sentence_2 = nlp(df.iloc[i][1])
    similarityValue.append(sentence_1.similarity(sentence_2))
    print(sentence_1, '|', sentence_2, '|', sentence_1.similarity(sentence_2))

df['Similarity'] = similarityValue
print(df)
# Out:
# Hello, How Can I help you today? | Hello, How Can I help you today? | 1.0
# Hello, How Can I help you today? | Hello, How Can I help you today? | 1.0
# Hello, How Can I help you today? | Hello, How Can I help you today? | 1.0
# Our Agent will respond to the ticket within 16 Hrs. Kindly note that our support is only available from Monday to Saturday. You can also call our Agents on this Number : 9999999999 (Time: 10AM to 6 PM). | Our Agent will respond to the ticket within 16 Hrs. Kindly note that our support is only available from Monday to Saturday. You can also call our Agents on this Number : 9999999999 (Time: 10AM to 6 PM). | 1.0
# ...

# %%
similarityValue = []

for i in range(df.count()[0]):
    sentence_1 = nlp(df.iloc[i][0])
    sentence_2 = nlp(df.iloc[i][1])
    similarityValue.append(sentence_1.similarity(sentence_2))
    #print(sentence_1, '|', sentence_2, '|', sentence_1.similarity(sentence_2))

df['Similarity'] = similarityValue
df2 = df['Similarity'].mean()
print("Accuracy of ChatBot is")
print( df2)
# Out:
# Accuracy of ChatBot is
# 0.978315890279103
